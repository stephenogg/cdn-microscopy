# %%
pressures = [0.273,0.275]

# %%
pressures
# Out:
# [0.273, 0.275]

# %%
len(pressures)
# Out:
# 2

# %%
pressures[0]
# Out:
# 0.273

# %%
pressures[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pressures[2]
#
# IndexError: list index out of range

# %%
pressures[0] = 0.265

# %%
pressures
# Out:
# [0.265, 0.275]

# %%
pressures[2] = 0.282
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pressures[2] = 0.282
#
# IndexError: list assignment index out of range

# %%
pressures.append(0.277)

# %%
pressures
# Out:
# [0.265, 0.275, 0.277]

# %%
pressures.append([0.123, 0.245])

# %%
pressures
# Out:
# [0.265, 0.275, 0.277, [0.123, 0.245]]

# %%
del pressures[-1]

# %%
pressures
# Out:
# [0.265, 0.275, 0.277]

# %%
pressures.extend([0.123,0.576])

# %%
pressures
# Out:
# [0.265, 0.275, 0.277, 0.123, 0.576]

# %%
[]
# Out:
# []

# %%
pressures[2:]
# Out:
# [0.277, 0.123, 0.576]

# %%
import ty
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import ty
#
# ModuleNotFoundError: No module named 'ty'

# %%
total = 0
for char in "tin":
    total = total + 1
total
# Out:
# 3

# %%
original = "tin"
result = ""
for char in original:
    result = char + result
print(result)
# Out:
# nit

# %%
total = 0
for word in ["red", "green", "blue"]:
    total = total + len(word)
print(total)
# Out:
# 12

# %%
# List of word lengths: ["red", "green", "blue"] => [3, 5, 4]
lengths = []
for word in ["red", "green", "blue"]:
    lengths.append(len(word))
print(lengths)
# Out:
# [3, 5, 4]

# %%
original = [-1.5, 0.2, 0.4, 0.0, -1.3, 0.4]
result = []
for element in original:
    if element < 0:
        result.append(0)
    else:
        result.append(1)
print(result)
# Out:
# [0, 1, 1, 1, 0, 1]

# %%
import glob
import pandas as pd
for filename in glob.glob('data/*.csv'):
    contents = pd.read_csv(filename)
    ____:
        print(filename, len(contents))

# %%
def print_time(hour, minute, second):
   time_string = str(hour) + ':' + str(minute) + ':' + str(second)
   print(time_string)

result = print_time(11, 37, 59)
# Out:
# 11:37:59

# %%
import pandas as pd

def min_in_data(filename):
    data = pd.read_csv(filename
    return data.min()

# %%
def first_negative(values):
    if len(values) == 0:
        return None
    for v in values:
        if v < 0:
    return v

# %%
def get_egg_label(mass):
    egg_label = ""
    if mass >= 85:
        egg_label = "jumbo"
    elif mass >= 70:
        egg_label = "large"
    elif mass < 70 and mass >= 55:
        egg_label ="medium"
    else:
        egg_label = "small" # revised version
    return egg_label
import random
for i in range(10):

    # simulating the mass of a chicken egg
    # the (random) mass will be 70 +/- 20 grams
    mass = 70 + 20.0 * (2.0 * random.random() - 1.0)

    print(mass, get_egg_label(mass))
# Out:
# 58.74314674621259 medium
# 82.43082884293727 large
# 54.385535266379534 small
# 50.79711594642698 small
# 88.01791405387559 jumbo
# 77.0575431676869 large
# 80.1275822313288 large
# 58.650417317441985 medium
# 67.53006416231881 medium
# 74.97988714740579 large

# %%
def middle(a, b, c):
    '''Return the middle value of three.
    Assumes the values can actually be compared.'''
    values = [a, b, c]
    values.sort()
    return values[1]

# %%
help(middle)
# Out:
# Help on function middle in module __main__:
#
# middle(a, b, c)
#     Return the middle value of three.
#     Assumes the values can actually be compared.
